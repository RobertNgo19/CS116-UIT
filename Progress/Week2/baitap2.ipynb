# %%
pip install geopandas
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 1.0 MB 8.5 MB/s
# ...
#      |████████████████████████████████| 6.3 MB 57.2 MB/s
# ...
#      |████████████████████████████████| 16.7 MB 48.6 MB/s
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
from shapely.geometry import Point,Polygon
import geopandas as gpd 
import descartes
import folium

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = gpd.read_file('/content/drive/MyDrive/population_shapefile/population_shapefile/Population_Ward_Level.shp')
df
# Out:
#              Com_Name    Dist_Name Com_ID Dist_ID Level  Pop_2009  Pop_2019  \
# 0            Tan Dinh   District 1  26734     760  Ward   26571.0   23258.0
# 1            Ben Nghe   District 1  26740     760  Ward   13580.0   10633.0
# 2        Cau Ong Lanh   District 1  26752     760  Ward   12917.0   10737.0
# 3    Nguyen Thai Binh   District 1  26746     760  Ward   13197.0    9716.0
# 4            Co Giang   District 1  26755     760  Ward   18967.0   11517.0
# ..                ...          ...    ...     ...   ...       ...       ...
# 317    Tan Hung Thuan  District 12  26787     761  Ward   28892.0   33467.0
# 318           Ward 17       Go Vap  26875     764  Ward   44226.0   54728.0
# 319            Ward 8       Go Vap  26898     764  Ward   26545.0   32778.0
# 320            Ward 9       Go Vap  26897     764  Ward   26785.0   34596.0
# 321           Ward 12       Go Vap  26881     764  Ward   50356.0   60502.0
#
#      Den_2009  Den_2019   Shape_Leng    Shape_Area  \
# ...

# %%
a =df.loc[df['Shape_Area']==df['Shape_Area'].max()]
print("Phuong co dien tich cao nhat la:",
      ''.join(a['Com_Name'].values),
      ''.join(a['Dist_Name'].values))
# Out:
# Phuong co dien tich cao nhat la: Ly Nhon Can Gio

# %%
a= df.loc[df['Pop_2019']==df['Pop_2019'].max()]
print("Phuong co dan so 2019 cao nhat la:", 
      ''.join(a['Com_Name'].values),
      ' '.join(a['Dist_Name'].values))
# Out:
# Phuong co dan so 2019 cao nhat la: Vinh Loc A Binh Chanh

# %%
a =df.loc[df['Shape_Area']==df['Shape_Area'].min()]
print("Phuong co dien tich nho nhat la:",
      ''.join(a['Com_Name'].values),
      ''.join(a['Dist_Name'].values))
# Out:
# Phuong co dien tich nho nhat la: Ward 3 District 10

# %%
a = df.loc[df['Pop_2019']==df['Pop_2019'].min()]
print("Phuong co dan so 2019 thap nhat la:", 
      ''.join(a['Com_Name'].values),
      ''.join(a['Dist_Name'].values))
# Out:
# Phuong co dan so 2019 thap nhat la: An Khanh District 2

# %%
b=df[df['growth_speed']==df['growth_speed'].max()]
print("Phuong co toc do tang truong dan so nhanh nhat (dua tren Pop_2009 va Pop_2019): ",
      ''.join(b['Com_Name'].values),
      ''.join(b['Dist_Name']))
# Out:
# Phuong co toc do tang truong dan so nhanh nhat (dua tren Pop_2009 va Pop_2019):  Phu Huu District 9

# %%
b=df[df['growth_speed']==df['growth_speed'].min()]
print("Phuong co toc do tang truong dan so cham nhat (dua tren Pop_2009 va Pop_2019): ",
      ''.join(b['Com_Name'].values),
      ''.join(b['Dist_Name']))
# Out:
# Phuong co toc do tang truong dan so cham nhat (dua tren Pop_2009 va Pop_2019):  An Khanh District 2

# %%
df['pop_change']= df['Pop_2019']-df['Pop_2009']
df
# Out:
#              Com_Name    Dist_Name Com_ID Dist_ID Level  Pop_2009  Pop_2019  \
# 0            Tan Dinh   District 1  26734     760  Ward   26571.0   23258.0
# 1            Ben Nghe   District 1  26740     760  Ward   13580.0   10633.0
# 2        Cau Ong Lanh   District 1  26752     760  Ward   12917.0   10737.0
# 3    Nguyen Thai Binh   District 1  26746     760  Ward   13197.0    9716.0
# 4            Co Giang   District 1  26755     760  Ward   18967.0   11517.0
# ..                ...          ...    ...     ...   ...       ...       ...
# 317    Tan Hung Thuan  District 12  26787     761  Ward   28892.0   33467.0
# 318           Ward 17       Go Vap  26875     764  Ward   44226.0   54728.0
# 319            Ward 8       Go Vap  26898     764  Ward   26545.0   32778.0
# 320            Ward 9       Go Vap  26897     764  Ward   26785.0   34596.0
# 321           Ward 12       Go Vap  26881     764  Ward   50356.0   60502.0
#
#      Den_2009  Den_2019   Shape_Leng    Shape_Area  \
# ...

# %%
c=df[df['pop_change']==df['pop_change'].max()]
print("Phuong co bien dong dan so nhanh nhat: ",''.join(c['Com_Name']),''.join(c['Dist_Name']))
# Out:
# Phuong co bien dong dan so nhanh nhat:  Vinh Loc A Binh Chanh

# %%
c=df[df['pop_change']==df['pop_change'].min()]
print("Phuong co bien dong dan so cham nhat: ",''.join(c['Com_Name']),''.join(c['Dist_Name']))
# Out:
# Phuong co bien dong dan so cham nhat:  An Khanh District 2

# %%
c=df[df['Den_2019']==df['Den_2019'].max()]
print("Phuong co mat do dan so cao nhat: ",''.join(c['Com_Name']),''.join(c['Dist_Name']))
# Out:
# Phuong co mat do dan so cao nhat:  Ward 8 District 4

# %%
c=df[df['Den_2019']==df['Den_2019'].min()]
print("Phuong co mat do dan so thap nhat: ",''.join(c['Com_Name']),''.join(c['Dist_Name']))
